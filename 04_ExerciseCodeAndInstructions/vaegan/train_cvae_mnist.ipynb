# %% [markdown]
# # Conditional VAE
# Train a conditional VAE on the MNIST handwritten digit dataset.
#
# This makes use of: our custom Keras model class defined in vaegan.vae.py, our
# class for loading the MNIST dataset defined in vaegan.data, and our custom Keras
# callback in vaegan.callbacks.
#
# A directory called 'output' will be created to save figures and the trained
# model.

# %%
nEpochs=20  # orig, longer training
# nEpochs=3  # quick testing during development

# %% [markdown]
# ## 1. Import 3rd party libraries

# %%
import os
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from importlib import reload

# %% [markdown]
# ## 2. Import our own classes (that we will complete together)

# %%
# Import our own classes 
from vaegan.data import MNIST
from vaegan.conditional.callbacks import SaveImagesConditional
import vaegan.vae

# %% [markdown]
# ## 3. Show some our data

# %%
# Create output directory if it doesn't exist yet.
output_dir = './outputs/mnist_cvae'
os.makedirs(output_dir, exist_ok=True)
    
# Instantiate the MNIST class containing our training data.
data = MNIST()

# One-hot encode the labels
n_classes = int(data.labels_train.max() + 1)
labels_onehot = tf.one_hot(data.labels_train, 
                           depth=n_classes,
                           dtype=tf.float32).numpy()

# Show some example images and their labels.
data.show_example_images(os.path.join(output_dir, 'example_images.png'))
# Out:
# I0000 00:00:1748623677.888682   26448 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15494 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:02:00.0, compute capability: 6.0
# I0000 00:00:1748623677.892483   26448 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 4788 MB memory:  -> device: 1, name: Tesla P100-PCIE-16GB, pci bus id: 0000:82:00.0, compute capability: 6.0

# %% [markdown]
# ## 4. Construct the model using the python class you completed

# %%
pyModule = reload(vaegan.vae)
    
# Create the model. Note that we're using mostly the default arguments, but this is
# where you might want to play around with different loss weights.
tf.random.set_seed(1234)
model = pyModule.ConditionalVAE(n_classes=n_classes)

# This step tells Keras to compute the explicit output shapes of each layer.
# Otherwise, the layers will have dynamic/variable output shapes which is not
# compatible with saving and loading.
# model.compute_output_shape([(None, 32, 32, 1), (None, n_classes)])
# model.decoder.compute_output_shape((None, 18))
# Out:
# Loaded version: vaegan.vae
# Loaded version: vaegan.vae

# %% [markdown]
# ## <span style="color:blue"> Correct model dimensions </span>
#
#
# <span style="color:blue"> === OVERALL MODEL ==== </span>
#
# ```
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder (Encoder)            multiple                  243456
# _________________________________________________________________
# decoder (Decoder)            multiple                  192385
# _________________________________________________________________
# recon_loss (Mean)            multiple                  2
# _________________________________________________________________
# kl_loss (Mean)               multiple                  2
# _________________________________________________________________
# total_loss (Mean)            multiple                  2
# =================================================================
# Total params: 435,847
# Trainable params: 435,137
# Non-trainable params: 710
# __________________________
#
# ```
# <span style="color:blue"> === ENCODER SUBMODEL ====</span>
# ```
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 32, 32, 11)] 0
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, 32, 32, 16)   2832        input_4[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, 32, 32, 16)   64          conv0[0][0]
# __________________________________________________________________________________________________
# relu0 (ReLU)                    (None, 32, 32, 16)   0           bn0[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 16, 16, 32)   8224        relu0[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 16, 16, 32)   128         conv1[0][0]
# __________________________________________________________________________________________________
# relu1 (ReLU)                    (None, 16, 16, 32)   0           bn1[0][0]
# __________________________________________________________________________________________________
# conv2 (Conv2D)                  (None, 8, 8, 64)     32832       relu1[0][0]
# __________________________________________________________________________________________________
# bn2 (BatchNormalization)        (None, 8, 8, 64)     256         conv2[0][0]
# __________________________________________________________________________________________________
# relu2 (ReLU)                    (None, 8, 8, 64)     0           bn2[0][0]
# __________________________________________________________________________________________________
# conv3 (Conv2D)                  (None, 4, 4, 64)     65600       relu2[0][0]
# __________________________________________________________________________________________________
# bn3 (BatchNormalization)        (None, 4, 4, 64)     256         conv3[0][0]
# __________________________________________________________________________________________________
# relu3 (ReLU)                    (None, 4, 4, 64)     0           bn3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           relu3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          131200      flatten[0][0]
# __________________________________________________________________________________________________
# dense_mean (Dense)              (None, 8)            1032        dense[0][0]
# __________________________________________________________________________________________________
# dense_logvar (Dense)            (None, 8)            1032        dense[0][0]
# ==================================================================================================
# Total params: 243,456
# Trainable params: 243,104
# Non-trainable params: 352
#
# ```
# <span style="color:blue"> === DECODER SUBMODEL ====</span>
# ```
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 18)]              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              19456
# _________________________________________________________________
# relu_dense (ReLU)            (None, 1024)              0
# _________________________________________________________________
# reshape (Reshape)            (None, 4, 4, 64)          0
# _________________________________________________________________
# tconv0 (Conv2DTranspose)     (None, 8, 8, 64)          65600
# _________________________________________________________________
# bn0 (BatchNormalization)     (None, 8, 8, 64)          256
# _________________________________________________________________
# relu0 (ReLU)                 (None, 8, 8, 64)          0
# _________________________________________________________________
# tconv1 (Conv2DTranspose)     (None, 16, 16, 64)        65600
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 16, 16, 64)        256
# _________________________________________________________________
# relu1 (ReLU)                 (None, 16, 16, 64)        0
# _________________________________________________________________
# tconv2 (Conv2DTranspose)     (None, 32, 32, 32)        32800
# _________________________________________________________________
# bn2 (BatchNormalization)     (None, 32, 32, 32)        128
# _________________________________________________________________
# relu2 (ReLU)                 (None, 32, 32, 32)        0
# _________________________________________________________________
# tconv3 (Conv2DTranspose)     (None, 32, 32, 16)        8208
# _________________________________________________________________
# bn3 (BatchNormalization)     (None, 32, 32, 16)        64
# _________________________________________________________________
# relu3 (ReLU)                 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv_out (Conv2D)            (None, 32, 32, 1)         17
# _________________________________________________________________
# sigmoid_out (Activation)     (None, 32, 32, 1)         0
# =================================================================
# Total params: 192,385
# Trainable params: 192,033
# Non-trainable params: 352
#
# ```
# ## 5. Now check your model's  dimensions against this list above

# %%
print("=== OVERALL MODEL ====")
model.summary()
print("=== ENCODER SUBMODEL ====")
enc_in = tf.keras.layers.Input((32,32,11)) # 32x32x1 + 10 more in the last dim for the one-hot encoded class label
enc_out  = model.encoder.call(enc_in) 
enc = tf.keras.Model(enc_in, enc_out) 
enc.summary()
print("=== DECODER SUBMODEL ====")
dec_in = tf.keras.layers.Input(shape=(model.n_latent_dims+10,)) 
dec_out  = model.decoder.call(dec_in) 
dec = tf.keras.Model(dec_in, dec_out) 
dec.summary()
# Out:
# === OVERALL MODEL ====
# Model: "cvae"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ encoder (Encoder)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoder (Decoder)               │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# === ENCODER SUBMODEL ====
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 32, 32,    │          0 │ -                 │
# │ (InputLayer)        │ 11)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv0 (Conv2D)      │ (None, 32, 32,    │      2,832 │ input_layer_2[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn0                 │ (None, 32, 32,    │         64 │ conv0[0][0]       │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ relu0 (ReLU)        │ (None, 32, 32,    │          0 │ bn0[0][0]         │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1 (Conv2D)      │ (None, 16, 16,    │      8,224 │ relu0[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn1                 │ (None, 16, 16,    │        128 │ conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ relu1 (ReLU)        │ (None, 16, 16,    │          0 │ bn1[0][0]         │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2 (Conv2D)      │ (None, 8, 8, 64)  │     32,832 │ relu1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn2                 │ (None, 8, 8, 64)  │        256 │ conv2[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ relu2 (ReLU)        │ (None, 8, 8, 64)  │          0 │ bn2[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3 (Conv2D)      │ (None, 4, 4, 64)  │     65,600 │ relu2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn3                 │ (None, 4, 4, 64)  │        256 │ conv3[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ relu3 (ReLU)        │ (None, 4, 4, 64)  │          0 │ bn3[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 1024)      │          0 │ relu3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │    131,200 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_mean (Dense)  │ (None, 8)         │      1,032 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_logvar        │ (None, 8)         │      1,032 │ dense[0][0]       │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 243,456 (951.00 KB)
#  Trainable params: 243,104 (949.62 KB)
#  Non-trainable params: 352 (1.38 KB)
# === DECODER SUBMODEL ====
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 18)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │        19,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu_dense (ReLU)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ tconv0 (Conv2DTranspose)        │ (None, 8, 8, 64)       │        65,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn0 (BatchNormalization)        │ (None, 8, 8, 64)       │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu0 (ReLU)                    │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ tconv1 (Conv2DTranspose)        │ (None, 16, 16, 64)     │        65,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn1 (BatchNormalization)        │ (None, 16, 16, 64)     │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu1 (ReLU)                    │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ tconv2 (Conv2DTranspose)        │ (None, 32, 32, 32)     │        32,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn2 (BatchNormalization)        │ (None, 32, 32, 32)     │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu2 (ReLU)                    │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ tconv3 (Conv2DTranspose)        │ (None, 32, 32, 16)     │         8,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn3 (BatchNormalization)        │ (None, 32, 32, 16)     │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu3 (ReLU)                    │ (None, 32, 32, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_out (Conv2D)               │ (None, 32, 32, 1)      │            17 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sigmoid_out (Activation)        │ (None, 32, 32, 1)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 192,385 (751.50 KB)
#  Trainable params: 192,033 (750.13 KB)
#  Non-trainable params: 352 (1.38 KB)

# %% [markdown]
# ## 6. Compile the model

# %%
# Compile the model with an optimizer. The learning rate of the optimizer can be
# specified here. Normally, this is also where you would select a loss function
# and any metrics. However, our custom model defines the loss functions inside
# its __init__ constructor, so we don't need to do that here. 
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001))

# Instantiate our custom callback to save a few example reconstructions and
# generated images after each epoch.
save_images_callback = SaveImagesConditional(output_dir=output_dir, 
                                             model=model,
                                             example_images=data.images_train[:10],
                                             example_labels=labels_onehot[:10],
                                             n_generated_images=10,
                                             n_latent_dims=model.n_latent_dims)

# %% [markdown]
# ## 7. Train (fit) the model on the data

# %%
# Train the model. Just like any off-the-shelf Keras model, we just call fit.
# Under the hood, Keras will call the train_step method of our custom subclass
# on each mini-batch and automatically loop through the training data. It will
# take care of all the details, like converting numpy arrays to tensors, showing
# a progress bar, and tracking the loss over the epochs.
logs = model.fit([data.images_train, labels_onehot],
                 batch_size=128,
                 epochs=1,
                 callbacks=[save_images_callback])
# Out:
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - kl_loss: 5.6423 - recon_loss: 83.4949 - total_loss: 89.1373

# %%
# Train the model. Just like any off-the-shelf Keras model, we just call fit.
# Under the hood, Keras will call the train_step method of our custom subclass
# on each mini-batch and automatically loop through the training data. It will
# take care of all the details, like converting numpy arrays to tensors, showing
# a progress bar, and tracking the loss over the epochs.
logs = model.fit([data.images_train, labels_onehot],
                 batch_size=128,
                 epochs=nEpochs,
                 callbacks=[save_images_callback])
# Out:
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - kl_loss: 8.0245 - recon_loss: 23.9905 - total_loss: 32.0150
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - kl_loss: 8.5739 - recon_loss: 20.3231 - total_loss: 28.8971
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - kl_loss: 8.8126 - recon_loss: 18.8023 - total_loss: 27.6149
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - kl_loss: 8.9822 - recon_loss: 17.8306 - total_loss: 26.8128
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - kl_loss: 9.1112 - recon_loss: 17.1059 - total_loss: 26.2171
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - kl_loss: 9.2184 - recon_loss: 16.6094 - total_loss: 25.8279
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - kl_loss: 9.2552 - recon_loss: 16.2428 - total_loss: 25.4980
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - kl_loss: 9.3284 - recon_loss: 15.9328 - total_loss: 25.2612
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - kl_loss: 9.3517 - recon_loss: 15.7057 - total_loss: 25.0574
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - kl_loss: 9.4002 - recon_loss: 15.4983 - total_loss: 24.8985
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - kl_loss: 9.4496 - recon_loss: 15.2669 - total_loss: 24.7165
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - kl_loss: 9.4497 - recon_loss: 15.1884 - total_loss: 24.6381
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - kl_loss: 9.4975 - recon_loss: 15.0032 - total_loss: 24.5007
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - kl_loss: 9.5317 - recon_loss: 14.8630 - total_loss: 24.3947
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - kl_loss: 9.5665 - recon_loss: 14.7806 - total_loss: 24.3470
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - kl_loss: 9.5088 - recon_loss: 14.7113 - total_loss: 24.2201
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - kl_loss: 9.5645 - recon_loss: 14.5871 - total_loss: 24.1515
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - kl_loss: 9.6012 - recon_loss: 14.4557 - total_loss: 24.0569
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - kl_loss: 9.6218 - recon_loss: 14.4162 - total_loss: 24.0380
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - kl_loss: 9.6003 - recon_loss: 14.3289 - total_loss: 23.9291

# %% [markdown]
# ## 8. Training saves results to disk, now also plot training curves

# %%
# Plot the training curves, which are stored in logs.history as a dict. Keys of
# this dict are the metric names, while the corresponding values are arrays.
fig, ax = plt.subplots()

for loss_name in ['recon_loss', 'kl_loss', 'total_loss']:
    loss_values = logs.history[loss_name]
    x = np.arange(len(loss_values))
    ax.plot(x, loss_values, label=loss_name)
    
ax.legend()
ax.set_xlabel('Epoch')
fig.savefig(os.path.join(output_dir, 'training_curves_2o.png'), transparent=False)
fig.show()

# Save the model 
model.save(os.path.join(output_dir, 'cvae.keras'))

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

# --- Config ---
n_latent_dims = 8
n_classes = 10
image_shape = (32, 32, 1)
output_dir = 'output_cvae_test'
os.makedirs(output_dir, exist_ok=True)

# --- Load Model ---
model = pyModule.ConditionalVAE(n_latent_dims, n_classes, image_shape)
_ = model([tf.zeros((1, *image_shape)), tf.zeros((1, n_classes))])  # Build
model.load_weights('outputs/mnist_cvae/cvae.keras')
print("Model weights loaded.")
data = MNIST()
# You can optionally show some examples to verify:
# data.show_example_images(num_examples=5, train_set=False) # Show test images

# --- Config (from your original script) ---
n_latent_dims = 8
n_classes = 10 # MNIST has 10 classes (0-9)
image_shape = (32, 32, 1) # This should match the output of data.preprocess_images
output_dir = 'output_cvae_test_with_custom_mnist'
os.makedirs(output_dir, exist_ok=True)


# --- Generate Dummy Test Data ---
num_samples = 16
images = data.images_test
labels_int = data.labels_test 
labels_onehot = tf.one_hot(labels_int, depth=n_classes).numpy()

# --- Reconstruct Images ---
try:
    recon = model.predict([images, labels_onehot])
except Exception:
    recon = model([tf.constant(images), tf.constant(labels_onehot)], training=False).numpy()

# --- Visualization: Original vs Reconstructed ---
plt.figure(figsize=(12, 6))
for i in range(num_samples):
    for j, img in enumerate([images[i], recon[i]]):  # j=0: original, j=1: recon
        ax = plt.subplot(4, 8, i * 2 + j + 1)
        plt.imshow(img.squeeze(), cmap='gray')
        plt.title(("Orig", "Recon")[j] + f": {labels_int[i]}")
        plt.axis('off')
plt.tight_layout()
save_path = os.path.join(output_dir, 'test_reconstructions.png')
plt.savefig(save_path)
plt.show()
print(f"Test reconstructions saved to {save_path}")

# --- Generate New Images by Class ---
n_gen = n_classes * 2
z = tf.random.normal((n_gen, n_latent_dims))
gen_labels = np.array([i % n_classes for i in range(n_gen)])
gen_onehot = tf.one_hot(gen_labels, depth=n_classes)
gen_input = tf.concat([z, gen_onehot], axis=-1)
gen_images = model.decoder(gen_input, training=False).numpy()

plt.figure(figsize=(12, 6))
for i, img in enumerate(gen_images):
    ax = plt.subplot((n_gen + 7) // 8, 8, i + 1)
    plt.imshow(img.squeeze(), cmap='gray')
    plt.title(f"Gen: {gen_labels[i]}")
    plt.axis('off')
plt.tight_layout()
save_path_gen = os.path.join(output_dir, 'generated_images_by_class.png')
plt.savefig(save_path_gen)
plt.show()
print(f"Generated images saved to {save_path_gen}")
# Out:
# Loaded version: vaegan.vae
# Loaded version: vaegan.vae
# I0000 00:00:1748623714.892502   26448 cuda_dnn.cc:529] Loaded cuDNN version 90300
# Model weights loaded.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1748623718.066452   27000 service.cc:152] XLA service 0x2aaea8003110 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1748623718.066497   27000 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1748623718.066501   27000 service.cc:160]   StreamExecutor device (1): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2025-05-30 11:48:38.090873: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#  57/313 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# I0000 00:00:1748623719.256400   27000 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Test reconstructions saved to output_cvae_test_with_custom_mnist/test_reconstructions.png
# Generated images saved to output_cvae_test_with_custom_mnist/generated_images_by_class.png

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

def visualize_latent_space_effects(decoder_model,
                                   target_digit,
                                   n_lantent_dim=8,
                                   num_interp=9,
                                   latent_sweep_range=(-3, 3)):
    """
    Visualizes the effect of varying individual latent dimensions on a generative model's output.

    Args:
        decoder_model (tf.keras.Model): The trained decoder part of a cvae.
        target_digit (int): The digit for which to explore latent effects.
    """

    # Generate a linear space of values to sweep through for a latent dimension
    interp_v = np.linspace(latent_sweep_range[0], latent_sweep_range[1], num_interp)

    # Create one-hot encoded labels for the target digit
    # Assuming 10 classes for digits 0-9
    digit_labels = tf.one_hot([target_digit] * num_interp, depth=10)

    # Set up the plot: a grid of n_lantent_dim rows and num_interp columns
    fig, axes = plt.subplots(n_lantent_dim,
                             num_interp,
                             figsize=(num_interp, n_lantent_dim))
    fig.suptitle(f"Latent Dimension Effects for Digit {target_digit}", fontsize=16, y=0.98) # Adjusted y for suptitle

    # Iterate over each latent dimension to explore
    for dim_index in range(n_lantent_dim):
        # Initialize a batch of latent vectors (all zeros)
        # Each row is a latent vector for one interpolation step
        latent_vector = np.zeros((num_interp, n_lantent_dim), dtype=np.float32)

        # Modify the current 'dim_index'-th latent dimension with the interp_v
        latent_vector[:, dim_index] = interp_v

        # Concatenate latent vectors with one-hot encoded labels for conditional generation
        con_decoder_input = tf.concat([latent_vector, digit_labels], axis=1)

        # Generate images using the decoder model
        # 'training=False' is important for models with layers like BatchNormalization or Dropout
        generated_images = decoder_model(con_decoder_input, training=False).numpy()

        # Plot the generated images for the current latent dimension
        for step_index in range(num_interp):
            ax = axes[dim_index, step_index]
            
            ax.imshow(generated_images[step_index].squeeze(), cmap='gray')
            ax.axis("off")

        # Set y-label for the first plot in each row to indicate the latent dimension
        axes[dim_index, 0].set_ylabel(f"z{dim_index}")
    plt.tight_layout()
    plt.show()

# %%
visualize_latent_space_effects(model.decoder, target_digit=1)
visualize_latent_space_effects(model.decoder, target_digit=3)
visualize_latent_space_effects(model.decoder, target_digit=7)
